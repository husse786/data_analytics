# %%
from ollama import Client

client = Client()

response = client.generate("llama2", "What is the capital of France?")

print(response)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 5
#       1 from ollama import Client
#       3 client = Client()
# ----> 5 response = client.generate("llama2", "What is the capital of France?")
#       7 print(response)
#
# File ~/.local/lib/python3.11/site-packages/ollama/_client.py:256, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, raw, format, images, options, keep_alive)
#     229 def generate(
#     230   self,
#     231   model: str = '',
#    (...)    244   keep_alive: Optional[Union[float, str]] = None,
#     245 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     246   """
#     247   Create a response using the requested model.
#     248
#    (...)    253   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     254   """
# ...
